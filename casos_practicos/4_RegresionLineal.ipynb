# %% [markdown]
# # Regresión Lineal: Coste de un incidente de seguridad

# %% [markdown]
# En este ejercicio se explican los fundamentos básicos de la regresión lineal aplicada a un caso de uso sencillo relacionado con la Ciberseguridad.

# %% [markdown]
# ## Enunciado del ejercicio

# %% [markdown]
# El ejercicio consiste en predecir el coste de un incidente de seguridad en base al número de equipos que se han visto afectados. El conjunto de datos es generado de manera aleatoria.

# %% [markdown]
# ### 0. Imports

# %%
# Instalacion de librerías externas
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (1.24.4)
# Requirement already satisfied: matplotlib in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.2-cp38-cp38-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\usuario\documents\ejercicios\python-ds\.venv\lib\site-packages (from scikit-learn) (1.24.4)
# Collecting scipy>=1.5.0 (from scikit-learn)
#   Downloading scipy-1.10.1-cp38-cp38-win_amd64.whl.metadata (58 kB)
#      ---------------------------------------- 0.0/59.0 kB ? eta -:--:--
#      ---------------------------------------- 59.0/59.0 kB 1.0 MB/s eta 0:00:00
# Collecting joblib>=1.1.1 (from scikit-learn)
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.3.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.3.2-cp38-cp38-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB 5.9 MB/s eta 0:00:02
#    -- ------------------------------------- 0.6/9.3 MB 6.8 MB/s eta 0:00:02
#    -------- ------------------------------- 1.9/9.3 MB 13.2 MB/s eta 0:00:01
#    ------------ --------------------------- 2.9/9.3 MB 15.3 MB/s eta 0:00:01
#    --------------------- ------------------ 5.1/9.3 MB 21.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.5/9.3 MB 23.1 MB/s eta 0:00:01
#    ------------------------------------- -- 8.6/9.3 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  9.3/9.3 MB 27.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 23.7 MB/s eta 0:00:00
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ---------------------------------------- 0.0/302.2 kB ? eta -:--:--
#    --------------------------------------- 302.2/302.2 kB 18.2 MB/s eta 0:00:00
# Downloading scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
#    ---------------------------------------- 0.0/42.2 MB ? eta -:--:--
#    -- ------------------------------------- 2.3/42.2 MB 49.2 MB/s eta 0:00:01
#    ---- ----------------------------------- 4.3/42.2 MB 45.2 MB/s eta 0:00:01
#    ----- ---------------------------------- 5.4/42.2 MB 38.6 MB/s eta 0:00:01
#    ------ --------------------------------- 7.0/42.2 MB 37.0 MB/s eta 0:00:01
#    -------- ------------------------------- 8.8/42.2 MB 37.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 10.6/42.2 MB 36.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 11.6/42.2 MB 34.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 12.6/42.2 MB 31.2 MB/s eta 0:00:01
#    ------------- -------------------------- 14.0/42.2 MB 29.7 MB/s eta 0:00:01
#    --------------- ------------------------ 16.0/42.2 MB 32.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 17.0/42.2 MB 34.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 17.0/42.2 MB 28.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 18.9/42.2 MB 28.5 MB/s eta 0:00:01
#    ------------------- -------------------- 20.8/42.2 MB 27.3 MB/s eta 0:00:01
#    -------------------- ------------------- 21.5/42.2 MB 23.4 MB/s eta 0:00:01
#    ------------------------ --------------- 25.4/42.2 MB 28.5 MB/s eta 0:00:01
#    --------------------------- ------------ 29.5/42.2 MB 40.9 MB/s eta 0:00:01
#    ------------------------------ --------- 31.7/42.2 MB 54.4 MB/s eta 0:00:01
#    ------------------------------- -------- 33.1/42.2 MB 43.7 MB/s eta 0:00:01
#    --------------------------------- ------ 35.5/42.2 MB 40.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 37.9/42.2 MB 38.5 MB/s eta 0:00:01
#    ------------------------------------- -- 40.1/42.2 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------- 42.2/42.2 MB 17.2 MB/s eta 0:00:00
# Downloading threadpoolctl-3.3.0-py3-none-any.whl (17 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.3.2 scikit-learn-1.3.2 scipy-1.10.1 threadpoolctl-3.3.0

# %% [markdown]
# ### 1. Generación del conjunto de datos

# %%
import numpy as numpy

# %%
import numpy as np

X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

print("La longitud del conjunto de datos es:", len(X))
# Out:
# La longitud del conjunto de datos es: 100

# %% [markdown]
# ### 2. Visualización del conjunto de datos

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(X, y, "b.")
plt.show()

# %%
plt.plot(X, y, "b.")
plt.xlabel("Equipos afectados (u/1000)")
plt.ylabel("Coste del incidente (u/10000)")
plt.show()

# %% [markdown]
# ### 3. Modificación del conjunto de datos

# %%
import pandas as pd

# %%
data = {'n_equipos_afectados': X.flatten(), 'coste': y.flatten()}
df = pd.DataFrame(data)
df.head(10)
# Out:
#    n_equipos_afectados      coste
# 0             0.073475   3.860190
# 1             0.468622   5.124184
# 2             1.810995   9.202983
# 3             0.395113   5.356555
# 4             1.417518   7.733563
# 5             0.998593   8.925218
# 6             1.651056  10.030994
# 7             0.612416   5.640671
# 8             0.495412   5.334297
# 9             1.238331   8.610203

# %%
# Escalado del número de equipos afectados
df['n_equipos_afectados'] = df['n_equipos_afectados'] * 1000
df['n_equipos_afectados'] = df['n_equipos_afectados'].astype('int')
# Escalado del coste
df['coste'] = df['coste'] * 10000
df['coste'] = df['coste'].astype('int')
df.head(10)
# Out:
#    n_equipos_afectados   coste
# 0                   73   38601
# 1                  468   51241
# 2                 1810   92029
# 3                  395   53565
# 4                 1417   77335
# 5                  998   89252
# 6                 1651  100309
# 7                  612   56406
# 8                  495   53342
# 9                 1238   86102

# %%
# Representación gráfica del conjunto de datos
plt.plot(df['n_equipos_afectados'], df['coste'], "b.")
plt.xlabel("Equipos afectados")
plt.ylabel("Coste del incidente")
plt.show()

# %% [markdown]
# ### 4. Construcción del modelo

# %%
from sklearn.linear_model import LinearRegression

# %%
# Construcción del modelo y ajuste de la función hipótesis
lin_reg = LinearRegression()
lin_reg.fit(df['n_equipos_afectados'].values.reshape(-1, 1), df['coste'].values)
# Out:
# LinearRegression()

# %%
# Parámetro theta 0
lin_reg.intercept_
# Out:
# 40716.430586925446

# %%
# Parámetro theta 1
lin_reg.coef_
# Out:
# array([29.91526775])

# %%
# Predicción para el valor mínimo y máximo del conjunto de datos de entrenamiento
X_min_max = np.array([[df["n_equipos_afectados"].min()], [df["n_equipos_afectados"].max()]])
y_train_pred = lin_reg.predict(X_min_max)

# %%
# Representación gráfica de la función hipótesis generada
plt.plot(X_min_max, y_train_pred, "g-")
plt.plot(df['n_equipos_afectados'], df['coste'], "b.")
plt.xlabel("Equipos afectados")
plt.ylabel("Coste del incidente")
plt.show()

# %% [markdown]
# ### 5. Predicción de nuevos ejemplos

# %%
x_new = np.array([[1300],[1900]]) # 1300 equipos afectados

# Predicción del coste que tendría el incidente
coste = lin_reg.predict(x_new) 

print("El coste del incidente sería:", int(coste[0]), "€")
# Out:
# El coste del incidente sería: 79606 €

# %%
plt.plot(df['n_equipos_afectados'], df['coste'], "b.")
plt.plot(X_min_max, y_train_pred, "g-")
plt.plot(x_new, coste, "rx")
plt.xlabel("Equipos afectados")
plt.ylabel("Coste del incidente")
plt.show()
